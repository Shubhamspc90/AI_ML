# %% [markdown]
# 🗂️ 01. Introduction
# Iska role kya hai?
#
# Ye Scikit-learn ka introduction tha.
#
# Yahan humne dekha ki Machine Learning me Scikit-learn ka use hota hai.
#
# Kab use karte hain?
#
# Jab bhi Machine Learning model banana ho.
#
# 🗂️ 02. Data Preprocessing
# Iska role kya hai?
#
# Raw data almost kabhi bhi perfect nahi hota.
#
# Usko clean karna padta hai.
#
# Isme kya seekha?
# Missing Values
# Encoding
# Scaling
#
# Kab use karte hain?
#
# ✅ Model train karne se pehle.
#
# 🗂️ 03. Feature Engineering
# Iska role kya hai?
#
# Data se naye useful features banana.
#
# Example
#
# Date
#
# ↓
#
# Year
#
# Month
#
# Day
#
# Kab use karte hain?
#
# Jab original columns se aur information nikalni ho.
#
# 🗂️ 04. Train Test Split
# Iska role kya hai?
#
# Data ko do parts me divide karna.
#
# Training
#
# ↓
#
# Model Seekhta Hai
#
# Testing
#
# ↓
#
# Model ki Exam Hoti Hai
#
# Kab use karte hain?
#
# Har supervised ML project me.
#
# 🗂️ 05. Linear Regression
# Kis problem ke liye?
#
# Continuous value predict karna.
#
# Example
#
# House Price
# Salary
# Temperature
#
# Output
#
# 25000
#
# 500000
#
# 32.5
#
# 🗂️ 06. Logistic Regression
# Kis problem ke liye?
#
# Yes / No type prediction.
#
# Example
#
# Spam
#
# Not Spam
#
# Disease
#
# No Disease
#
# Pass
#
# Fail
#
# 🗂️ 07. KNN
# Kya karta hai?
#
# Apne nearest neighbours ko dekhkar prediction karta hai.
#
# Example
#
# Agar 5 paas wale students Pass hain
#
# ↓
#
# To ye bhi Pass.
#
# Kab use karte hain?
#
# Small datasets.
#
# 🗂️ 08. Decision Tree
# Kya karta hai?
#
# Questions puchta hai.
#
# Age > 18 ?
#
# ↓
#
# Yes
#
# ↓
#
# Income > 50000 ?
#
# ↓
#
# Loan Approved
#
# Tree ki tarah decision leta hai.
#
# 🗂️ 09. Random Forest
# Kya karta hai?
#
# Ek tree nahi,
#
# Bahut saare trees.
#
# Fir voting karta hai.
#
# Tree 1
#
# ↓
#
# Yes
#
# Tree 2
#
# ↓
#
# No
#
# Tree 3
#
# ↓
#
# Yes
#
# Final
#
# ↓
#
# Yes
#
# Fayda
#
# Decision Tree se jyada accurate hota hai.
#
# 🗂️ 10. Naive Bayes
# Kya karta hai?
#
# Probability ke basis par prediction.
#
# Example
#
# Email
#
# ↓
#
# Contains "Win"
#
# ↓
#
# Spam Probability
#
# Fast algorithm.
#
# Mostly
#
# Spam Detection
# Text Classification
#
# 🗂️ 11. Support Vector Machine (SVM)
# Kya karta hai?
#
# Classes ke beech best boundary banata hai.
#
# Cats
#
# |
#
# Boundary
#
# |
#
# Dogs
#
# Jitni achhi boundary,
#
# Utni achhi prediction.
#
# 🗂️ 12. K-Means
# Sabse alag.
#
# Yahan target hi nahi hota.
#
# Ye khud groups banata hai.
#
# Example
#
# Mall Customers
#
# ↓
#
# Rich Customers
#
# ↓
#
# Medium Customers
#
# ↓
#
# Budget Customers
#
# Kab use karte hain?
#
# Customer Segmentation.
#
# 🗂️ 13. PCA
# Kya karta hai?
#
# Data ko chhota bana deta hai.
#
# Example
#
# 20 Features
#
# ↓
#
# 5 Features
#
# Information almost same rehti hai.
#
# Fayda
#
# Model fast ho jata hai.
#
# 🗂️ 14. Cross Validation
# Kya karta hai?
#
# Model ki ek baar nahi,
#
# Kai baar exam leta hai.
#
# Split 1
#
# ↓
#
# Accuracy
#
# Split 2
#
# ↓
#
# Accuracy
#
# Average
#
# ↓
#
# Final Accuracy
#
# Fayda
#
# Result jyada trustworthy hota hai.
#
# 🗂️ 15. Hyperparameter Tuning
# Kya karta hai?
#
# Model ki settings improve karta hai.
#
# Example
#
# Decision Tree
#
# Depth = 2
#
# ↓
#
# Accuracy 88%
#
# Depth = 5
#
# ↓
#
# Accuracy 95%
#
# Automatically best setting choose karta hai.
#
# 🗂️ 16. Pipeline
# Kya karta hai?
#
# Saare steps ko ek line me jod deta hai.
#
# Without Pipeline
#
# Scaling
#
# ↓
#
# Training
#
# ↓
#
# Prediction
#
# With Pipeline
#
# Pipeline
#
# ↓
#
# Sab Automatically
#
# Code clean ho jata hai.
#
# 🗂️ 17. ColumnTransformer
# Kya karta hai?
#
# Different columns ke liye different preprocessing.
#
# Example
#
# Age
#
# ↓
#
# Scaling
#
# Salary
#
# ↓
#
# Scaling
#
# City
#
# ↓
#
# Encoding
#
# Ek hi jagah sab manage karta hai.
#
# 🗂️ 18. Joblib & Pickle
# Kya karta hai?
#
# Model ko save karta hai.
#
# Train Model
#
# ↓
#
# Save
#
# ↓
#
# Later Load
#
# ↓
#
# Prediction
#
# Har baar training nahi karni padti.
#
# 🧠 Ab ek poora flow dekho
#
# Yahi flow hum project me follow karenge:
#
# Dataset
#
# ↓
#
# Data Cleaning
# (02)
#
# ↓
#
# Feature Engineering
# (03)
#
# ↓
#
# Train Test Split
# (04)
#
# ↓
#
# Choose Algorithm
# (05-11)
#
# ↓
#
# Cross Validation
# (14)
#
# ↓
#
# Hyperparameter Tuning
# (15)
#
# ↓
#
# Pipeline
# (16)
#
# ↓
#
# ColumnTransformer
# (17)
#
# ↓
#
# Train Best Model
#
# ↓
#
# Save Model
# (18)
#
# ↓
#
# Prediction
