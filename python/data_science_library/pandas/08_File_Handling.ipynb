# %% [markdown]
# **1️. Read CSV File**

# %%
import pandas as pd
df = pd.read_csv("../datasets/students.csv")

print(df)
# Out:
#     Name  Age  Marks    City
# 0  Rahul   20     90   Delhi
# 1   Aman   21     85  Mumbai
# 2   Riya   22     95    Pune
# 3  Karan   20     88   Delhi
# 4  Priya   23     92  Mumbai
# 5   Neha   21     75    Pune

# %% [markdown]
# **2️. Write CSV File**

# %%
df.to_csv("../datasets/output.csv", index=False)

# %% [markdown]
# **3️. Read Excel File**

# %%
#  # problem hai esme


df = pd.read_excel("../datasets/students.xlsx")

print(df)
print(df.head())
print(df.shape)
print(df.columns)
# Out:
#     Name  Age  Marks
# 0  Rahul   20     90
# 1   Aman   21     85
# 2   Riya   22     95

# %% [markdown]
# **4️. Write Excel File**

# %%
###  esme bhiproblem hai

df.to_excel("../datasets/output.xlsx", index=False)

# %% [markdown]
# **5️. Read JSON File**

# %%
df = pd.read_json("../datasets/students.json")

print(df)
# Out:
#    Student_ID   Name  Age  Gender     City Course  Marks
# 0         101   Amit   20    Male    Delhi    BCA     85
# 1         102  Priya   21  Female   Mumbai    BSc     92
# 2         103  Rahul   19    Male   Jaipur   BCom     76
# 3         104  Sneha   22  Female  Lucknow    BCA     88
# 4         105  Arjun   20    Male     Pune  BTech     91

# %% [markdown]
# **6️. Write JSON File**

# %%
df.to_json(
    "../datasets/output.json",
    orient="records",
    indent=4
)

# %% [markdown]
# **7️. Relative Path**

# %%
df = pd.read_csv("../datasets/students.csv")

# %% [markdown]
# **8️. Absolute Path**

# %%
df = pd.read_csv(
    "E:/AI Learning/AI_ML/python/data_science_library/datasets/students.csv"
)

# %% [markdown]
# **9️. Read Selected Columns**

# %%
df = pd.read_csv(
    "../datasets/students.csv",
    usecols=["Name", "Marks"]
)

print(df)
# Out:
#     Name  Marks
# 0  Rahul     90
# 1   Aman     85
# 2   Riya     95
# 3  Karan     88
# 4  Priya     92
# 5   Neha     75

# %% [markdown]
# **10. Read First Few Rows**

# %%
df = pd.read_csv(
    "../datasets/students.csv",
    nrows=3
)

print(df)
# Out:
#     Name  Age  Marks    City
# 0  Rahul   20     90   Delhi
# 1   Aman   21     85  Mumbai
# 2   Riya   22     95    Pune

# %% [markdown]
# **11. Save Without Index**

# %%
df.to_csv(
    "../datasets/new_students.csv",
    index=False
)
