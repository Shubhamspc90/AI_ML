# %%
# # Project Objective

# Classify Cats and Dogs using Google's pretrained MobileNetV2 model.

# %%
# # Complete Project Flow

# Dataset

# ↓

# Preprocessing

# ↓

# MobileNetV2

# ↓

# Freeze Base Model

# ↓

# Dense Layers

# ↓

# Training

# ↓

# Evaluation

# ↓

# Prediction

# ↓

# Save Model

# %%
# # What is Transfer Learning?

# Transfer Learning means reusing the knowledge learned from one problem to solve another related problem.

# Instead of training from scratch, we use a pretrained model.

# %%
# # What is ImageNet?

# ImageNet contains millions of labeled images across 1000 classes.

# Most pretrained CNN models are trained on ImageNet.

# %%
# # Why MobileNetV2?

# - Lightweight
# - Fast
# - Accurate
# - Suitable for Mobile Devices
# - Excellent Feature Extractor

# %%
# # Important APIs

# MobileNetV2()

# GlobalAveragePooling2D()

# Dense()

# Dropout()

# compile()

# fit()

# evaluate()

# predict()

# save()

# %%
# # Interview Questions

# Q1. What is Transfer Learning?

# Q2. What is ImageNet?

# Q3. Why MobileNetV2?

# Q4. What is include_top=False?

# Q5. Why Freeze the Base Model?

# Q6. What is GlobalAveragePooling2D?

# Q7. Why Sigmoid?

# Q8. What is Fine-Tuning?

# Q9. Difference between CNN and Transfer Learning?

# Q10. Why use pretrained weights?

# %%
# # Common Mistakes

# ❌ Forgetting include_top=False

# ❌ Not Freezing the Base Model

# ❌ Wrong Input Image Size

# ❌ Missing Image Normalization

# ❌ Training Entire MobileNetV2 on Small Dataset

# %%
# # Resume Points

# • Built a Transfer Learning image classifier using MobileNetV2.

# • Used pretrained ImageNet weights for feature extraction.

# • Added custom classification layers.

# • Applied EarlyStopping to reduce overfitting.

# • Generated prediction reports and saved trained model.

# • Improved development speed using Transfer Learning.

# %%
# 03_Cats_vs_Dogs_Transfer_Learning
# │
# ├── dataset
# │   ├── training_set
# │   └── test_set
# ├── notebook
# │   ├── Transfer_Learning_MobileNetV2.ipynb
# │   └── 00_Project_Review_Transfer_Learning.ipynb
# ├── outputs
# │   ├── predictions.png
# │   └── predictions.csv
# ├── saved_model
# │   └── mobilenetv2_cats_dogs.keras
# ├── README.md
# └── requirements.txt
